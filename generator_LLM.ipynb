# %%
import os
import pandas as pd
import numpy as np
import torch

# %% [markdown]
# # Load Dataset

# %%
data_1 = pd.read_csv('artist_song_lyrics.csv')

# %%
data_2 = pd.read_csv('data/topSongsLyrics1950_2019.csv',usecols = ['Artist','Song','Lyrics'])

# %%
data_2.head()
# Out:
#            Artist                            Song  \
# 0     Fats Domino                     The Fat Man
# 1  Percy Mayfield  Please Send Me Someone To Love
# 2      Ruth Brown          Teardrops From My Eyes
# 3   Nat King Cole                       Mona Lisa
# 4      Patti Page                 Tennessee Waltz
#
#                                               Lyrics
# 0  They call, they call me the fat man|'Cause I w...
# 1  Understanding and peace of mind|But, if it's n...
# 2  I think of you|And that's the time|I feel so b...
# 3  Mona Lisa, Mona Lisa, men have named you|You'r...
# 4  When an old friend I happened to see|I Introdu...

# %%
data_1.shape, data_2.shape
# Out:
# ((99, 3), (701, 3))

# %%
#concatenate the two datasets
data = pd.concat([data_1, data_2])

# %%
data.shape
# Out:
# (800, 3)

# %% [markdown]
# # Data Exploration

# %%
data.shape
# Out:
# (800, 3)

# %%
data.describe()
# Out:
#          Artist    Song                                             Lyrics
# count       800     800                                                796
# unique      506     755                                                796
# top     Beatles  Closer  ['This is the end', 'Hold your breath and coun...
# freq         12       3                                                  1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, 0 to 700
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Artist  800 non-null    object
#  1   Song    800 non-null    object
#  2   Lyrics  796 non-null    object
# dtypes: object(3)
# memory usage: 25.0+ KB

# %%
#drop rows with null values
data.dropna(axis=0,inplace=True)

# %%
data.shape
# Out:
# (796, 3)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 796 entries, 0 to 700
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Artist  796 non-null    object
#  1   Song    796 non-null    object
#  2   Lyrics  796 non-null    object
# dtypes: object(3)
# memory usage: 24.9+ KB

# %% [markdown]
# # Data Processing

# %%
import string

# create translator that replaces punctuation with empty spaces
translator = str.maketrans("", "", string.punctuation)

# %%
# remove punctuation characters and convert all chars to lowercase
data['Lyrics'] = data['Lyrics'].apply(lambda x: x.translate(translator).lower() if isinstance(x, str) else x)

# %%
data.tail()
# Out:
#                      Artist                 Song  \
# 696          Jonas Brothers               Sucker
# 697           Ariana Grande              7 rings
# 698            Travis Scott  Highest in the Room
# 699  Cardi B and Bruno Mars            Please Me
# 700             Post Malone              Circles
#
#                                                 Lyrics
# 696  we go togetherbetter than birds of a feather y...
# 697  yeah breakfast at tiffanys and bottles of bubb...
# 698  i got room in my fumes yeahshe fill my mind up...
# 699  uh uh yeah come onplease me babyturn around an...
# 700  oh oh ohoh  oh ohoh  oh oh oh ohwe couldnt tur...

# %%
data.reset_index(inplace = True, drop = True)

# %%
from collections import Counter
from collections import OrderedDict

#Get top 5 words used in each song's lyrics
for row in range(0,data.shape[0]):
    words = data['Lyrics'][row].split() #split text into words
    word_frequency = Counter(words) #Use Counter to count the freq of each word
    word_frequency = sorted(word_frequency.items(), key=lambda item: (-item[1], item[0])) #sort frequencies

    df_dict = pd.DataFrame(OrderedDict(word_frequency).items(),columns= ['word','frequency']) #convert sorted freqs to ordereddict and add data to df 
    print(df_dict.head())
# Out:
#     word  frequency
# 0     it         18
# 1    the         17
# 2  stand         14
# 3     we         14
# 4   fall         13
#       word  frequency
# 0        i         27
# 1      you         17
# 2     your         13
# 3      for         11
# 4  another         10
#          word  frequency
# 0       sugar         27
# 1  watermelon         25
# 2        high         23
# 3           i         17
# 4        just          9
#    word  frequency
# 0   you         37
# 1    it         26
# 2    to         24
# 3    me         15
# 4  keep         13
#         word  frequency
# 0    thunder         73
# 1        the         26
# 2  lightning         10
# 3       feel          9
# 4       then          9
#   word  frequency
# 0   im         22
# 1    i         17
# 2  the         16
# 3   in         15
# 4  you         15
#    word  frequency
# 0  yeah         47
# 1  babe         32
# 2   the         29
# 3  that         27
# 4    on         20
#    word  frequency
# 0     i         30
# 1   you         19
# 2   and         13
# 3  knew         13
# 4    me          9
#     word  frequency
# 0      i         27
# 1    you         17
# 2   they         11
# 3     it          8
# 4  would          8
#     word  frequency
# 0      i         12
# 1    ooh         12
# 2      a         11
# 3    the         10
# 4  youre         10
#    word  frequency
# 0     i         38
# 1   you         28
# 2   the         18
# 3  that         15
# 4    it         14
#   word  frequency
# 0  the         28
# 1  and         17
# 2    i         17
# 3   on         12
# 4   my          9
#    word  frequency
# 0   the         29
# 1    it         22
# 2  yeah         17
# 3   pop         14
# 4     i         11
#      word  frequency
# 0      it         37
# 1   blame         29
# 2      my         29
# 3  yayaee         28
# 4      on         25
#       word  frequency
# 0       im         22
# 1  dancing         19
# 2     with         15
# 3      you         14
# 4  tonight         13
#        word  frequency
# 0       the         32
# 1  memories         20
# 2      back         19
# 3     bring         19
# 4        to         14
#    word  frequency
# 0   the         20
# 1    in         13
# 2  gaga         12
# 3  lady         12
# 4     i          6
#    word  frequency
# 0   you         39
# 1     i         28
# 2   and         26
# 3    me         21
# 4  that         19
#    word  frequency
# 0     i         50
# 1    la         28
# 2    as         16
# 3  need         16
# 4  dont         14
#    word  frequency
# 0   you         29
# 1   the         18
# 2    to         18
# 3  know         13
# 4  dont         11
#    word  frequency
# 0    on         40
# 1  come         37
# 2    my         33
# 3     i         30
# 4   and         27
#     word  frequency
# 0   next         42
# 1    you         39
# 2  thank         37
# 3   yeah         15
# 4      i         14
#   word  frequency
# 0    i         22
# 1  the         15
# 2   im         10
# 3  hey          9
# 4   oh          7
#   word  frequency
# 0    i         18
# 1  you         16
# 2  and         13
# 3  the         13
# 4   to         11
#    word  frequency
# 0   the         32
# 1    me         22
# 2    of         20
# 3  love         16
# 4   you         16
#    word  frequency
# 0   you         36
# 1     i         18
# 2    my         17
# 3  that         16
# 4  when         16
#    word  frequency
# 0  yeah         41
# 1   you         35
# 2     i         26
# 3    me         24
# 4    my         15
#    word  frequency
# 0  away         21
# 1   run         21
# 2     i         13
# 3   the         12
# 4   you         10
#    word  frequency
# 0   guy         16
# 1    im         14
# 2   bad         13
# 3   you          9
# 4  your          9
#     word  frequency
# 0      i         25
# 1  sorry         20
# 2    you         17
# 3     im         13
# 4     is         12
#        word  frequency
# 0       the         29
# 1        me         23
# 2       you         21
# 3        my         20
# 4  believer         18
#    word  frequency
# 0     a         30
# 1  this         25
# 2    in         24
# 3     i         23
# 4  some         20
#         word  frequency
# 0        you         35
# 1       funk         29
# 2     uptown         29
# 3         up         25
# 4  dohdohdoh         19
#   word  frequency
# 0    i         24
# 1   ya         16
# 2  you         16
# 3  ooh         14
# 4  for         11
#     word  frequency
# 0    awe         27
# 1    you         19
# 2      a         16
# 3    the         16
# 4  youre         13
#       word  frequency
# 0       im         23
# 1      for         21
# 2       on         20
# 3  tonight         16
# 4      the         15
#       word  frequency
# 0     like         39
# 1        a         28
# 2   bright         27
# 3  diamond         24
# 4    shine         23
#   word  frequency
# 0   me         23
# 1  you         22
# 2    i         21
# 3   im         14
# 4   it         14
#    word  frequency
# 0   the         21
# 1  yeah         17
# 2   you         15
# 3    my         13
# 4    in         12
#     word  frequency
# 0      i         17
# 1    the         16
# 2     my         14
# 3    mmm         12
# 4  chris          9
#    word  frequency
# 0  yeah         39
# 1   the         37
# 2     i         27
# 3     a         19
# 4    to         17
#     word  frequency
# 0  bitch         19
# 1      a         17
# 2     im         17
# 3    ooh         14
# 4      i         13
#    word  frequency
# 0   you         37
# 1     i         19
# 2    me         19
# 3  know         14
# 4   the         12
#     word  frequency
# 0   high         34
# 1      a         32
# 2    had         24
# 3  hopes         17
# 4      i         17
#   word  frequency
# 0   to         23
# 1    i         21
# 2  the         14
# 3  you         14
# 4  and         12
#     word  frequency
# 0    the         16
# 1  older         15
# 2      i         14
# 3     we         14
# 4   aint         13
#    word  frequency
# 0   mum         45
# 1    my         32
# 2  cant         30
# 3  face         30
# 4  read         30
#     word  frequency
# 0  young         37
# 1   dumb         28
# 2  broke         19
# 3    and         13
# 4   high          9
#          word  frequency
# 0      1908nn          1
# 1           n          1
# 2  ntimestamp          1
# 3           –          1
#   word  frequency
# 0  all         28
# 1  you         25
# 2   my         19
# 3   me         18
# 4   of         17
#    word  frequency
# 0    to         33
# 1     i         18
# 2    we         17
# 3  used         13
# 4   but         11
#     word  frequency
# 0  highs         16
# 1   lows         16
# 2    you         16
# 3     to         14
# 4      i         12
#    word  frequency
# 0    me          9
# 1  with          9
# 2     i          8
# 3  stay          8
# 4    to          7
#      word  frequency
# 0  havana         21
# 1     ooh         21
# 2      me         20
# 3    back         19
# 4    nana         17
#   word  frequency
# 0  you         35
# 1  the         31
# 2   it         19
# 3   to         19
# 4   in         18
#    word  frequency
# 0    it         21
# 1     i         19
# 2   the         15
# 3    to         14
# 4  even         12
#   word  frequency
# 0  the         23
# 1  you         22
# 2   it         19
# 3   in         17
# 4  had         16
#   word  frequency
# 0   no         18
# 1  one         18
# 2  you         16
# 3    i         13
# 4  the         13
#    word  frequency
# 0   you         58
# 1  what         23
# 2   are         20
# 3  doin         20
# 4    me         18
#    word  frequency
# 0   you         15
# 1   and         13
# 2  that         13
# 3    im         12
# 4    my         11
#        word  frequency
# 0       the         19
# 1       and         18
# 2  paradise         14
# 3       war         14
# 4      zone         14
#    word  frequency
# 0     i         35
# 1   the         15
# 2    it         14
# 3    is         13
# 4  this         13
#     word  frequency
# 0      i         45
# 1     it         33
# 2    now         33
# 3    you         26
# 4  right         24
#   word  frequency
# 0   to         56
# 1  you         32
# 2  the         31
# 3  get         25
# 4  ive         18
#   word  frequency
# 0    i         19
# 1  you         12
# 2   in         11
# 3   my         10
# 4  the          7
#        word  frequency
# 0         a         25
# 1       ayy         18
# 2      like         15
# 3       and         13
# 4  rockstar         13
#     word  frequency
# 0  shake         70
# 1      i         67
# 2     it         36
# 3    off         36
# 4  gonna         22
#    word  frequency
# 0     i         14
# 1    to         14
# 2  cant         12
# 3   the         12
# 4  like          9
#      word  frequency
# 0  wishin         26
# 1     and         20
# 2       i         19
# 3      me         18
# 4    they         12
#   word  frequency
# 0    i         23
# 1  you         19
# 2   it         16
# 3  the         13
# 4  but         12
#    word  frequency
# 0  your         55
# 1  want         53
# 2     i         47
# 3   bad         38
# 4  love         36
#    word  frequency
# 0   the         18
# 1    to         17
# 2    im         13
# 3  woah         13
# 4   age         12
#    word  frequency
# 0     i         57
# 1    it         36
# 2  love         31
# 3   but         27
# 4  cant         23
#    word  frequency
# 0     i         55
# 1    it         54
# 2    my         20
# 3   got         19
# 4  want         18
#   word  frequency
# 0  you         30
# 1    a         19
# 2  the         17
# 3    i         15
# 4  and         14
#      word  frequency
# 0    eyes         14
# 1   ocean         14
# 2   those         10
# 3     you          8
# 4  chorus          6
#        word  frequency
# 0       ayy         45
# 1        my         20
# 2       you         19
# 3       the         15
# 4  umbrella         15
#    word  frequency
# 0  yeah         63
# 1     i         29
# 2  like         26
# 3   you         26
# 4     a         16
#    word  frequency
# 0    we         49
# 1   are         23
# 2  show         23
# 3  them         23
# 4  lets         19
#    word  frequency
# 0   you         40
# 1   and         29
# 2     i         25
# 3    my         15
# 4  that         15
#    word  frequency
# 0  dont         29
# 1    up         22
# 2    me         21
# 3   you         16
# 4   out         15
#    word  frequency
# 0     i         56
# 1   you         28
# 2     a         23
# 3  dont         23
# 4   the         16
#     word  frequency
# 0    you         29
# 1      a         21
# 2   katy         12
# 3  perry         12
# 4    her         11
#       word  frequency
# 0        i         22
# 1      and         15
# 2       an         11
# 3  elastic         11
# 4      got         11
#       word  frequency
# 0      you         20
# 1        i         16
# 2      the         16
# 3      are         15
# 4  amazing         14
#      word  frequency
# 0  feelin         29
# 1     you         28
# 2      as         16
# 3    good         16
# 4    hell         16
#    word  frequency
# 0     i         17
# 1    in         16
# 2    my         14
# 3    it         12
# 4  like         11
#   word  frequency
# 0   of         20
# 1    a         18
# 2  the         14
# 3   to         12
# 4    i         10
#     word  frequency
# 0    you         20
# 1     we         19
# 2     of         17
# 3  ready         15
# 4    all         12
#        word  frequency
# 0        in         19
# 1   rihanna         18
# 2         a         17
# 3  hopeless         17
# 4      love         17
#      word  frequency
# 0     you         19
# 1     and         10
# 2   chris         10
# 3  martin         10
# 4    will          9
#    word  frequency
# 0   you         52
# 1    do         29
# 2  what         29
# 3  mean         28
# 4    oh         26
#     word  frequency
# 0   yeah         35
# 1      i         31
# 2    the         24
# 3    you         16
# 4  those         15
#    word  frequency
# 0     a         49
# 1   you         27
# 2     i         25
# 3    it         23
# 4  know         23
#    word  frequency
# 0     i         20
# 1   you         19
# 2   the         18
# 3    im         14
# 4  know         14
#      word  frequency
# 0     you         23
# 1       i         16
# 2      to         12
# 3      so         11
# 4  before          9
#     word  frequency
# 0     im         30
# 1  sorry         28
# 2   baby         23
# 3   that         15
# 4      i         14
#    word  frequency
# 0    to         27
# 1     i         26
# 2  want         17
# 3   you         16
# 4    go         15
#     word  frequency
# 0    you         28
# 1    the         22
# 2    and         17
# 3  jonas         13
# 4     im         12
#      word  frequency
# 0     wah         19
# 1  wahwah          7
# 2    goin          5
# 3       i          3
# 4     the          3
#   word  frequency
# 0   me         16
# 1   to         13
# 2  you         10
# 3  its          5
# 4  not          5
#       word  frequency
# 0      you          9
# 1       my          5
# 2      the          5
# 3      its          4
# 4  raining          4
#    word  frequency
# 0  mona          7
# 1     a          6
# 2    to          6
# 3   you          6
# 4  your          5
#         word  frequency
# 0          i          8
# 1         my          7
# 2        the          7
# 3  tennessee          5
# 4         to          5
#        word  frequency
# 0        me          7
# 1       and          6
# 2        im          6
# 3      gone          5
# 4  lonesome          5
#    word  frequency
# 0   new          6
# 1    my          5
# 2   see          5
# 3   the          5
# 4  down          4
#     word  frequency
# 0  movin         13
# 1     on         10
# 2    you          9
# 3     im          8
# 4    the          7
#      word  frequency
# 0  enough         11
# 1       a          8
# 2      oh          8
# 3       i          7
# 4     hes          6
#   word  frequency
# 0    a          7
# 1  the          5
# 2  and          4
# 3   be          4
# 4  are          3
#           word  frequency
# 0           em         10
# 1           15          8
# 2      minutes          8
# 3           of          8
# 4  sixtyminute          7
#      word  frequency
# 0     and          5
# 1      my          4
# 2       a          3
# 3      in          3
# 4  rocket          3
#       word  frequency
# 0       my          8
# 1        i          6
# 2  believe          4
# 3       in          4
# 4      the          4
#    word  frequency
# 0  your          7
# 1   and          5
# 2     a          4
# 3    on          3
# 4   you          3
#     word  frequency
# 0     to          5
# 1    too          5
# 2   were          5
# 3  young          5
# 4    may          4
#    word  frequency
# 0  your         11
# 1     i          9
# 2   and          8
# 3  cold          8
# 4    to          6
#     word  frequency
# 0    the         19
# 1     of         12
# 2      a         10
# 3    got          7
# 4  glory          5
#    word  frequency
# 0    my          8
# 1  cant          5
# 2     i          4
# 3   the          4
# 4    be          3
#      word  frequency
# 0   about          5
# 1    with          5
# 2       a          4
# 3     got          4
# 4  lookin          4
#      word  frequency
# 0     how         10
# 1     the          6
# 2  theres          6
# 3     you          6
# 4    high          4
#     word  frequency
# 0  lawdy          6
# 1    you          6
# 2   tell          4
# 3     to          4
# 4  gonna          3
#   word  frequency
# 0  the         16
# 1   me         12
# 2   on         12
# 3    a         10
# 4   my          8
#     word  frequency
# 0  mercy         13
# 1   know          6
# 2      i          5
# 3    you          5
# 4  babyi          4
#     word  frequency
# 0   mint         13
# 1      a          9
# 2  julep          8
# 3    was          7
# 4      i          6
#    word  frequency
# 0   you          8
# 1    my          6
# 2   and          4
# 3  back          4
# 4    be          4
#    word  frequency
# 0  cant          5
# 1    go          4
# 2    on          4
# 3    me          3
# 4    to          3
#   word  frequency
# 0   me         14
# 1  you         13
# 2    i          8
# 3   my          8
# 4    a          6
#      word  frequency
# 0     you         18
# 1      do         16
# 2  itdont         14
# 3      me         11
# 4    have          7
#     word  frequency
# 0    bop         18
# 1  honey         12
# 2    umm         12
# 3    you         10
# 4  wanna          8
#       word  frequency
# 0     will          7
# 1  cheatin          6
# 2    heart          6
# 3      the          6
# 4      and          4
#   word  frequency
# 0  the          8
# 1   to          6
# 2  and          5
# 3   of          5
# 4    i          4
#    word  frequency
# 0  love         15
# 1     i         12
# 2  that         11
# 3  dodo          6
# 4    me          6
#         word  frequency
# 0          a         15
# 1       hand          8
# 2      shake          6
# 3         to          6
# 4  handshake          5
#          word  frequency
# 0        hiyo          6
# 1        this          6
# 2         you          6
# 3          in          5
# 4  silverhiyo          5
#        word  frequency
# 0        he         13
# 1    treats         10
# 2  daughter          9
# 3      your          9
# 4        me          6
#     word  frequency
# 0    you         11
# 1   aint         10
# 2  hound          9
# 3      a          8
# 4     me          7
#     word  frequency
# 0     he          8
# 1    old          8
# 2  never          7
# 3      a          6
# 4    and          5
#        word  frequency
# 0        to         10
# 1       you          8
# 2         i          7
# 3       and          5
# 4  babylord          5
#      word  frequency
# 0    rock         31
# 1   gonna         21
# 2     the         17
# 3   clock         15
# 4  around         12
#      word  frequency
# 0     and         18
# 1  rattle         13
# 2   shake          9
# 3     the          9
# 4    roll          8
#     word  frequency
# 0    you         10
# 1      a          8
# 2   fool          8
# 3   love          8
# 4  earth          7
#     word  frequency
# 0     do         33
# 1  could         17
# 2     be         15
# 3      a         14
# 4  dream         10
#     word  frequency
# 0    all         14
# 1    dee         11
# 2  right         10
# 3  thats          7
# 4   mama          6
#       word  frequency
# 0       my          9
# 1     love          8
# 2     your          7
# 3  forever          6
# 4       in          6
#          word  frequency
# 0          to         14
# 1  sweetheart         12
# 2           i          9
# 3         its          9
# 4        well          9
#   word  frequency
# 0   me         13
# 1   oh         12
# 2    a          9
# 3   to          8
# 4  got          7
#     word  frequency
# 0   your          7
# 1    may          6
# 2    the          6
# 3  bells          5
# 4      a          4
#      word  frequency
# 0    good         13
# 1      me         13
# 2      so         12
# 3    with         12
# 4  goodso          5
#          word  frequency
# 0      frutti         25
# 1          oh         25
# 2  rootytutti         16
# 3          to          8
# 4        girl          7
#    word  frequency
# 0   you         15
# 1   the         11
# 2    be         10
# 3  cant         10
# 4   why         10
#       word  frequency
# 0        a          6
# 1  diddley          5
# 2     baby          4
# 3      his          3
# 4   pretty          3
#       word  frequency
# 0       do         10
# 1     fall         10
# 2       in          8
# 3  lovewhy          6
# 4        a          4
#    word  frequency
# 0    im          7
# 1    my          6
# 2     a          5
# 3  real          5
# 4   the          5
#    word  frequency
# 0  like         17
# 1     a         16
# 2   you         14
# 3   the         13
# 4     i          9
#   word  frequency
# 0    a         19
# 1  the         13
# 2   he         10
# 3  and          9
# 4  his          9
#     word  frequency
# 0   call         14
# 1     me         13
# 2    now         11
# 3   they         10
# 4  often          8
#     word  frequency
# 0      a          5
# 1     my          5
# 2  story          5
# 3      i          4
# 4    and          3
#    word  frequency
# 0    my         18
# 1    no         12
# 2  baby         11
# 3  dont         11
# 4   she         11
#    word  frequency
# 0     a         18
# 1  aint         18
# 2   you         18
# 3   was         12
# 4   all          6
#          word  frequency
# 0         fun         10
# 1        some         10
# 2          me          6
# 3     tonight          6
# 4  babyhaving          5
#        word  frequency
# 0      blue         18
# 1        my         15
# 2     suede         13
# 3       you         12
# 4  anything          7
#     word  frequency
# 0     be          8
# 1     to          8
# 2    you          8
# 3      a          6
# 4  cruel          6
#    word  frequency
# 0    my         14
# 1  baby         12
# 2  shes         12
# 3   the         12
# 4     i          7
#    word  frequency
# 0  over         11
# 1     a          9
# 2   and          9
# 3    my          7
# 4   the          6
#     word  frequency
# 0    the         18
# 1     of         10
# 2  still          8
# 3      i          7
# 4     in          4
#         word  frequency
# 0  blueberry          5
# 1         of          4
# 2       were          4
# 3         my          3
# 4   thrillon          3
#     word  frequency
# 0   love          6
# 1    you          6
# 2      i          5
# 3   baby          4
# 4  james          4
#    word  frequency
# 0    at         11
# 1  it’s          7
# 2   the          7
# 3   you          7
# 4    if          6
#         word  frequency
# 0        the         23
# 1         to         15
# 2  jailhouse         10
# 3         in          7
# 4       rock          7
#       word  frequency
# 0    berry          7
# 1      the          7
# 2  rosetta          5
# 3   tharpe          5
# 4        a          4
#      word  frequency
# 0      be         17
# 1     day         17
# 2     you         16
# 3     the         15
# 4  thatll         12
#       word  frequency
# 0      bye         19
# 1       my          8
# 2     love          6
# 3  lovebye          6
# 4       im          5
#    word  frequency
# 0    my          8
# 1    me          7
# 2  mine          6
# 3    it          5
# 4  love          5
#     word  frequency
# 0    the         23
# 1    and         11
# 2     to         11
# 3    you         11
# 4  round          5
#     word  frequency
# 0    you         25
# 1  dance         12
# 2  wanna         12
# 3   with         12
# 4      a         10
#     word  frequency
# 0  peggy         27
# 1    you         17
# 2      i         15
# 3   love         13
# 4  sueoh          9
#      word  frequency
# 0     you         12
# 1  please          7
# 2    baby          6
# 3    back          4
# 4    come          4
#      word  frequency
# 0   wanna          9
# 1     but          7
# 2     too          7
# 3       a          5
# 4  boogie          5
#      word  frequency
# 0  johnny         15
# 1      go         14
# 2    gogo         12
# 3     the         10
# 4       a          8
#      word  frequency
# 0       i          7
# 1     the          7
# 2       a          5
# 3      to          5
# 4  agonna          4
#     word  frequency
# 0   miss          9
# 1     to          9
# 2  golly          7
# 3   like          7
# 4  molly          7
#    word  frequency
# 0  love          6
# 1     i          4
# 2    so          3
# 3  will          3
# 4   and          2
#      word  frequency
# 0     the         14
# 1      in         12
# 2  little          6
# 3      of          5
# 4      be          4
#    word  frequency
# 0   yak          8
# 1  dont          7
# 2   the          5
# 3   you          5
# 4   out          4
#      word  frequency
# 0      ti          9
# 1  bailar          6
# 2      de          6
# 3      la          6
# 4    poca          6
#    word  frequency
# 0  dont         13
# 1  have         12
# 2     i          8
# 3   you          8
# 4   and          3
#       word  frequency
# 0      you         21
# 1      say         18
# 2     will          9
# 3      hey          5
# 4  willsay          5
#    word  frequency
# 0    me         26
# 1  feel         22
# 2  that         21
# 3   hey         18
# 4     i         18
#      word  frequency
# 0     bop         17
# 1     sha         17
# 2  bopsha          9
# 3       a          4
# 4    bopi          3
#    word  frequency
# 0   the          8
# 1     a          6
# 2  that          6
# 3    ol          5
# 4  just          4
#     word  frequency
# 0     my         14
# 1   goes         11
# 2    she         10
# 3   baby          5
# 4  there          5
#    word  frequency
# 0   the         11
# 1    of          6
# 2    to          4
# 3  like          3
# 4    me          3
#      word  frequency
# 0    city         10
# 1  kansas         10
# 2       i          9
# 3     and          8
# 4   gonna          8
#    word  frequency
# 0   you         14
# 1   ivy         10
# 2    da          8
# 3    la          8
# 4  make          8
#     word  frequency
# 0      i         35
# 1   what         35
# 2  thats         25
# 3   want         21
# 4  money          9
#      word  frequency
# 0       a          8
# 1       i          8
# 2      my          8
# 3     and          7
# 4  number          5
#     word  frequency
# 0      i          6
# 1  youre          6
# 2     so          5
# 3  about          4
# 4    and          4
#     word  frequency
# 0   love          9
# 1     me          7
# 2    the          7
# 3    you          6
# 4  still          5
#       word  frequency
# 0       my          7
# 1       on          7
# 2  georgia          5
# 3        i          5
# 4    sweet          5
#            word  frequency
# 0           the          4
# 1  animotionode          1
# 2           are          1
# 3        billie          1
# 4        bobbie          1
#    word  frequency
# 0  lets         16
# 1   the         12
# 2    go         11
# 3     a          9
# 4  upon          9
#      word  frequency
# 0      on         12
# 1    come          8
# 2     you          6
# 3  please          5
# 4      me          4
#   word  frequency
# 0  the         26
# 1   my         15
# 2  huh          9
# 3   of          9
# 4   on          9
#     word  frequency
# 0    you         15
# 1    the         12
# 2  dance          8
# 3    for          7
# 4   last          6
#      word  frequency
# 0    shop         30
# 1     you         28
# 2      uh         19
# 3  around         16
# 4     now         15
#      word  frequency
# 0     and          8
# 1   twist          8
# 2      on          7
# 3    baby          6
# 4  little          6
#      word  frequency
# 0   thats          7
# 1    want          6
# 2    your          6
# 3  cathys          5
# 4      he          5
#     word  frequency
# 0  stand         20
# 1     by         17
# 2    the          7
# 3   meoh          6
# 4   wont          6
#     word  frequency
# 0    for         11
# 1  crazy         10
# 2     im          3
# 3   love          3
# 4    and          2
#      word  frequency
# 0  around         22
# 1     the         14
# 2    roam         11
# 3       i         10
# 4      im         10
#    word  frequency
# 0  from         11
# 1   you          9
# 2   and          8
# 3  away          8
# 4   the          8
#      word  frequency
# 0     you          6
# 1       i          5
# 2    over          5
# 3  crying          4
# 4      me          3
#    word  frequency
# 0    no         32
# 1  dont         20
# 2  come         18
# 3  more         18
# 4    ya         18
#           word  frequency
# 0          run         12
# 1            i          8
# 2          why          8
# 3          the          5
# 4  runawayarun          4
#    word  frequency
# 0     i         11
# 1   the         10
# 2   you         10
# 3  with          9
# 4  that          8
#    word  frequency
# 0   and          7
# 1  will          5
# 2    as          4
# 3  dont          4
# 4   for          4
#      word  frequency
# 0      he          4
# 1  scared          4
# 2  runnin          3
# 3   would          3
# 4  afraid          2
#    word  frequency
# 0  yeah         29
# 1    to         11
# 2    it         10
# 3   you          7
# 4  your          7
#      word  frequency
# 0    hold         30
# 1      on         22
# 2  really         22
# 3     got         21
# 4       a         19
#    word  frequency
# 0   the         17
# 1    on         16
# 2    do         13
# 3  come          9
# 4  baby          8
#      word  frequency
# 0    come         22
# 1     out         18
# 2  sherry         11
# 3     you          9
# 4    baby          8
#    word  frequency
# 0    of          9
# 1  cant          6
# 2  live          6
# 3    my          6
# 4  stop          6
#    word  frequency
# 0   the         27
# 1    on         19
# 2    up         16
# 3   all          4
# 4  roof          4
#     word  frequency
# 0     it         40
# 1     on         30
# 2  shake         22
# 3    and         18
# 4     up         15
#    word  frequency
# 0  arms          5
# 1  hold          5
# 2  need          5
# 3   are          4
# 4     i          4
#    word  frequency
# 0   you         24
# 1  love         16
# 2   can         13
# 3    me         11
# 4    do          9
#     word  frequency
# 0   yeah         12
# 1  louie         10
# 2  gotta          9
# 3     oh          8
# 4     me          6
#     word  frequency
# 0    you         23
# 1   yeah         18
# 2  loves         13
# 3   know         11
# 4     be         10
#     word  frequency
# 0   your         14
# 1   hold         13
# 2  wanna         10
# 3  handi          8
# 4   that          7
#   word  frequency
# 0   my         41
# 1   be         23
# 2  and         12
# 3  you         11
# 4  one         10
#        word  frequency
# 0         i         16
# 1       her          8
# 2      with          7
# 3       saw          6
# 4  standing          6
#            word  frequency
# 0       outside         10
# 1          gone          7
# 2  surfinsurfin          7
# 3           and          3
# 4            be          3
#    word  frequency
# 0  glad         18
# 1   all         13
# 2    im         11
# 3   you          9
# 4  love          8
#     word  frequency
# 0    all         23
# 1    its         20
# 2  right         11
# 3      a          7
# 4    got          6
#    word  frequency
# 0   the         11
# 1  many         10
# 2   how          8
# 3   and          7
# 4    in          7
#      word  frequency
# 0    come         18
# 1      on         18
# 2       i         10
# 3  please          8
# 4      to          6
#   word  frequency
# 0  the        292
# 1    a        165
# 2    i        137
# 3  you        121
# 4   to         85
#            word  frequency
# 0           and          1
# 1        bodies          1
# 2         bombs          1
# 3          dead          1
# 4  launchersthe          1
#    word  frequency
# 0    my         19
# 1  girl          9
# 2  bout          7
# 3   got          7
# 4   the          6
#      word  frequency
# 0     got         29
# 1      me         22
# 2  really         19
# 3       i         10
# 4      so         10
#   word  frequency
# 0  the         11
# 1    a          8
# 2  new          4
# 3  and          3
# 4    i          3
#    word  frequency
# 0  baby         38
# 1  love         10
# 2    me          9
# 3   did          8
# 4   our          8
#        word  frequency
# 0     round         49
# 1       get         32
# 2    around         27
# 3         i         22
# 4  aroundim          7
#   word  frequency
# 0  all         15
# 1  the         13
# 2  and         12
# 3   of         12
# 4  day         10
#     word  frequency
# 0  woman         15
# 1    you          5
# 2   dont          4
# 3      i          4
# 4    the          4
#    word  frequency
# 0     a         12
# 1     i         12
# 2   you         10
# 3  been          9
# 4  feel          7
#   word  frequency
# 0    i          7
# 1   me          7
# 2  she          7
# 3  way          7
# 4  and          6
#    word  frequency
# 0    no         23
# 1  cant         21
# 2   get         20
# 3     i         19
# 4   and         12
#   word  frequency
# 0   to         15
# 1    a         13
# 2   it         12
# 3  the         11
# 4  you         11
#        word  frequency
# 0       the         12
# 1  midnight         10
# 2     gonna          8
# 3         i          6
# 4      wait          6
#      word  frequency
# 0  figaro         14
# 1     the         12
# 2   bravo          8
# 3      la          8
# 4       a          7
#          word  frequency
# 0          my         46
# 1        bout         26
# 2      talkin         18
# 3  generation         12
# 4          is         12
#   word  frequency
# 0  for          7
# 1   my          6
# 2   to          6
# 3    a          5
# 4  man          4
#    word  frequency
# 0     i         21
# 1     a         16
# 2  dont         13
# 3  care         11
# 4   she         11
#                word  frequency
# 0                 2          1
# 1         believin5          1
# 2             brent          1
# 3  congratulations4          1
# 4              dont          1
#      word  frequency
# 0      to         23
# 1       a         12
# 2    dont         12
# 3     got         12
# 4  ticket         12
#    word  frequency
# 0    my         16
# 1     a         10
# 2    of          9
# 3  look          8
# 4   you          8
#           word  frequency
# 0         good         25
# 1   vibrations         18
# 2  excitations         14
# 3           me         11
# 4       giving          9
#     word  frequency
# 0      a         11
# 1    his          6
# 2  loves          6
# 3    man          6
# 4     to          6
#    word  frequency
# 0   out         14
# 1   you         12
# 2  your         12
# 3    be         11
# 4    to         10
#      word  frequency
# 0    some         10
# 1  alovin          8
# 2    made          7
# 3   somea          7
# 4    glad          6
#     word  frequency
# 0   dont         19
# 1     to         18
# 2    you         17
# 3      i         10
# 4  leave         10
#    word  frequency
# 0    in          2
# 1   its          2
# 2  just          2
# 3  some          2
# 4  that          2
#              word  frequency
# 0           whats         14
# 1            look          7
# 2  soundeverybody          7
# 3            that          7
# 4          better          4
#       word  frequency
# 0      see         11
# 1       my          8
# 2  painted          8
# 3      and          7
# 4        i          7
#    word  frequency
# 0    me         18
# 1  dont         13
# 2   you         11
# 3   why          8
# 4    my          7
#          word  frequency
# 0        make          6
# 1           i          5
# 2  everything          3
# 3  groovywild          3
# 4       heart          3
#      word  frequency
# 0       a         34
# 1  little         27
# 2     you         17
# 3     bit         16
# 4      to         14
#     word  frequency
# 0     on         15
# 1     to         15
# 2    the          9
# 3   baby          8
# 4  light          8
#    word  frequency
# 0   you         12
# 1  with         11
# 2    my          8
# 3    be          6
# 4   the          6
#      word  frequency
# 0      me          5
# 1      my          4
# 2      no          4
# 3      or          4
# 4  purple          4
#          word  frequency
# 0         any         12
# 1          be         12
# 2        been         12
# 3       could         12
# 4  highwhat’s         12
#   word  frequency
# 0  the         14
# 1  her          7
# 2    a          6
# 3   at          6
# 4   of          6
#        word  frequency
# 0        to         17
# 1  somebody         16
# 2       you         15
# 3      love          5
# 4      your          5
#    word  frequency
# 0     a         23
# 1  soul         19
# 2   man         10
# 3   you          9
# 4     i          6
#      word  frequency
# 0      is          9
# 1     you          8
# 2       i          7
# 3  fields          6
# 4      to          6
#    word  frequency
# 0     i         17
# 1  love         16
# 2   the          8
# 3   how          6
# 4    is          5
#       word  frequency
# 0      you         20
# 1      the         15
# 2    heard         13
# 3       it         13
# 4  through         13
#        word  frequency
# 0       hey         23
# 1      jude         21
# 2  nananana         18
# 3        it         16
# 4      make         12
#     word  frequency
# 0    the         10
# 1  along          3
# 2     to          3
# 3    and          2
# 4    but          2
#      word  frequency
# 0     the         21
# 1    dock          7
# 2      of          6
# 3  sittin          6
# 4      im          5
#    word  frequency
# 0  yeah         36
# 1  mony         22
# 2     i          9
# 3    mo          8
# 4  come          5
#     word  frequency
# 0      a         17
# 1    its         15
# 2   jack          9
# 3    all          6
# 4  flash          6
#    word  frequency
# 0   the          7
# 1    be          6
# 2    to          6
# 3     a          5
# 4  your          5
#     word  frequency
# 0    the         14
# 1     in         10
# 2  where          4
# 3   dark          3
# 4   from          3
#     word  frequency
# 0    hoo         22
# 1     my         17
# 2    the         11
# 3  whats         10
# 4      a          9
#    word  frequency
# 0    to          6
# 1   you          5
# 2    be          4
# 3    of          4
# 4  what          4
#         word  frequency
# 0         my         14
# 1      lotta         12
# 2      whole         11
# 3        you         11
# 4  lovewanna          9
#      word  frequency
# 0      on         16
# 1  rollin         16
# 2     the         15
# 3    keep          6
# 4       a          5
#    word  frequency
# 0   you         30
# 1     i         28
# 2   buh         19
# 3  want         12
# 4    me         10
#     word  frequency
# 0  gimme         12
# 1    the         10
# 2  honky          8
# 3   tonk          8
# 4     to          5
#    word  frequency
# 0   the          8
# 1   bad          6
# 2  moon          5
# 3    on          5
# 4    to          5
#   word  frequency
# 0   do         37
# 1  you         17
# 2   it         11
# 3  are         10
# 4  the         10
#    word  frequency
# 0    ah         20
# 1  baby          6
# 2    oh          6
# 3    so          6
# 4     i          5
#       word  frequency
# 0        a         27
# 1     just         24
# 2     shot         19
# 3  awayits         15
# 4     kiss          6
#        word  frequency
# 0   meshoot         14
# 1  together         12
# 2       got         10
# 3        he         10
# 4  yeahcome          7
#    word  frequency
# 0     i         33
# 1    to         20
# 2   get         17
# 3  cant         16
# 4  next         16
#       word  frequency
# 0       my         10
# 1      you          8
# 2       me          5
# 3  begging          4
# 4  darling          4
#        word  frequency
# 0      will          8
# 1         a          7
# 2    bridge          6
# 3      over          6
# 4  troubled          6
#     word  frequency
# 0     it         41
# 1     be         21
# 2    let         14
# 3  belet         13
# 4     of         11
#    word  frequency
# 0   the         11
# 1     i          9
# 2   you          9
# 3  dont          7
# 4    in          7
#     word  frequency
# 0     on         77
# 1    get         51
# 2     up         38
# 3    the         26
# 4  upget         25
#   word  frequency
# 0  and         10
# 1    a          9
# 2    i          9
# 3  her          7
# 4  the          7
#      word  frequency
# 0     the         12
# 1       i          8
# 2   still          3
# 3    stop          3
# 4  wonder          3
#    word  frequency
# 0  seen         12
# 1     i         11
# 2   you          8
# 3   and          7
# 4   see          7
#    word  frequency
# 0     i          8
# 1    my          5
# 2    to          5
# 3   you          5
# 4  will          3
#     word  frequency
# 0  right         25
# 1    all         19
# 2    its         14
# 3   baby         12
# 4    now         12
#   word  frequency
# 0  the         15
# 1    a         14
# 2   to         12
# 3  you          8
# 4  all          6
#    word  frequency
# 0   the          8
# 1   all          4
# 2    im          4
# 3    no          4
# 4  only          3
#     word  frequency
# 0  whats         17
# 1  going         15
# 2     on         15
# 3  right         11
# 4     to          7
#     word  frequency
# 0    you          9
# 1     or          7
# 2    are          6
# 3  times          6
# 4      i          5
#   word  frequency
# 0    i         15
# 1    a         10
# 2  you         10
# 3   my          8
# 4   to          8
#   word  frequency
# 0  the         68
# 1    i         30
# 2  and         20
# 3  day         19
# 4    a         17
#   word  frequency
# 0  the         30
# 1  and         12
# 2   my         11
# 3  all          8
# 4  get          8
#    word  frequency
# 0     a          7
# 1  come          7
# 2  yeah          7
# 3  just          6
# 4  like          6
#    word  frequency
# 0    my         13
# 1  away          9
# 2  with          9
# 3     i          7
# 4     a          6
#         word  frequency
# 0          a         23
# 1     family         22
# 2  affairits         16
# 3         to          7
# 4      cause          4
#    word  frequency
# 0   you         10
# 1   the          7
# 2    in          6
# 3  dont          4
# 4  aint          3
#   word  frequency
# 0  was         27
# 1   he         24
# 2  his         19
# 3    a         12
# 4  all          9
#   word  frequency
# 0  the         19
# 1   on          6
# 2    a          5
# 3   in          4
# 4   to          4
#    word  frequency
# 0    me         18
# 1   you         13
# 2  call         12
# 3  need         11
# 4     a          9
#     word  frequency
# 0      a         12
# 1    for          9
# 2  heart          9
# 3     of          9
# 4     me          7
#            word  frequency
# 0        doodoo         40
# 1  doodoodoodoo         19
# 2           the         19
# 3             a         14
# 4            on         12
#    word  frequency
# 0    my         13
# 1    of          8
# 2   are          7
# 3   the          7
# 4  stay          5
#     word  frequency
# 0  never         24
# 1   know         20
# 2    you         14
# 3   dont         13
# 4     me         11
#       word  frequency
# 0      you         47
# 1     take         46
# 2       me         19
# 3  thereoh         11
# 4      let         10
#    word  frequency
# 0    me         24
# 1    to         24
# 2  roll         23
# 3   the         13
# 4    my          9
#      word  frequency
# 0     you         10
# 1    bird          9
# 2       i          9
# 3  cannot          6
# 4    cant          5
#    word  frequency
# 0    on         25
# 1   get         15
# 2    it         15
# 3   you         14
# 4  come         13
#        word  frequency
# 0        to         35
# 1       his         22
# 2  midnight         21
# 3       the         18
# 4     train         18
#    word  frequency
# 0   the         19
# 1   for         16
# 2    on          9
# 3    me          8
# 4  sing          8
#      word  frequency
# 0      da         70
# 1     the         33
# 2     for         29
# 3    just         27
# 4  enough         25
#   word  frequency
# 0    a         11
# 1    i          9
# 2  was          9
# 3  the          8
# 4   in          7
#    word  frequency
# 0     a         24
# 1   the         15
# 2    us          9
# 3   for          8
# 4  song          6
#      word  frequency
# 0     his         33
# 1    with         33
# 2      my         21
# 3      me         18
# 4  softly         16
#   word  frequency
# 0  the         14
# 1   to          9
# 2  you          7
# 3   my          5
# 4    a          4
#         word  frequency
# 0       that         18
# 1       lady         12
# 2       whos          9
# 3        her          8
# 4  beautiful          7
#     word  frequency
# 0     no         20
# 1  woman         15
# 2     to         12
# 3     be          8
# 4  going          8
#    word  frequency
# 0  home         14
# 1   the         10
# 2    to          6
# 3     i          5
# 4    im          5
#      word  frequency
# 0       i         22
# 1    aint         20
# 2    seen         17
# 3  nothin         11
# 4     you         10
#        word  frequency
# 0      your         27
# 1        me         15
# 2        in         14
# 3  armsrock         10
# 4   armsand          4
#       word  frequency
# 0       ya         27
# 1     avec         15
# 2  coucher         13
# 3   gitchi         10
# 4       go          9
#             word  frequency
# 0          fahrn        118
# 1            auf         44
# 2            der         44
# 3    autobahnwir         38
# 4  autobahnfahrn          4
#    word  frequency
# 0  love          9
# 1    in          6
# 2     i          5
# 3    me          5
# 4     a          4
#    word  frequency
# 0     i         12
# 1    my         12
# 2  woah         12
# 3    to          8
# 4    is          6
#      word  frequency
# 0       i         23
# 1      of         15
# 2    love         14
# 3    your         14
# 4  enough         12
#         word  frequency
# 0         me         29
# 1        you         15
# 2  something         10
# 3       tell          9
# 4       that          9
#   word  frequency
# 0  the         14
# 1   to         11
# 2   we         11
# 3   on          7
# 4    a          6
#   word  frequency
# 0  you         13
# 1   me         12
# 2    a         10
# 3  let          8
# 4   no          8
#       word  frequency
# 0      the         19
# 1     this         18
# 2        a         15
# 3  waywalk         12
# 4      was         10
#   word  frequency
# 0  the         11
# 1    i          8
# 2   my          8
# 3   of          8
# 4  let          6
#   word  frequency
# 0  the         24
# 1    a         18
# 2   to         16
# 3  was         16
# 4   in         15
#    word  frequency
# 0   you         10
# 1     a          7
# 2   for          5
# 3  from          4
# 4    in          3
#   word  frequency
# 0  the         22
# 1   in         10
# 2   to          9
# 3    a          7
# 4    i          7
#         word  frequency
# 0         of         28
# 1      these         24
# 2        the         10
# 3  nightsone          9
# 4        and          8
#      word  frequency
# 0       a          9
# 1  little          8
# 2   rider          7
# 3     low          4
# 4    trip          4
#    word  frequency
# 0  dont         12
# 1     a          8
# 2    in          7
# 3   not          7
# 4   you          7
#   word  frequency
# 0  the         24
# 1    a         12
# 2   to          9
# 3    i          6
# 4   in          6
#       word  frequency
# 0      can         16
# 1  another         12
# 2       go         12
# 3   lonely         12
# 4      own         12
#    word  frequency
# 0     a         14
# 1     i         13
# 2  more         12
# 3  than         12
# 4    my          6
#     word  frequency
# 0      i         12
# 1    the         11
# 2  wanna          7
# 3     be          6
# 4    use          4
#    word  frequency
# 0   the         21
# 1  that          7
# 2   you          7
# 3     a          6
# 4   can          6
#      word  frequency
# 0     the         13
# 1      la         12
# 2     and         10
# 3    fear          9
# 4  reaper          6
#        word  frequency
# 0       the         20
# 1     moves         18
# 2         i         13
# 3     night         12
# 4  remember          9
#   word  frequency
# 0  the         20
# 1   of          9
# 2  end          6
# 3  all          4
# 4   we          4
#       word  frequency
# 0      are         31
# 1     boys         31
# 2     back         29
# 3       in         28
# 4  townthe         19
#     word  frequency
# 0   that         29
# 1  funky         28
# 2  music         25
# 3    and         14
# 4      i         13
#      word  frequency
# 0  stayin         20
# 1    help         15
# 2      ah         12
# 3   alive         10
# 4    goin         10
#    word  frequency
# 0  will         16
# 1  rock          8
# 2    we          8
# 3   you          7
# 4  your          7
#    word  frequency
# 0    be         16
# 1   can         16
# 2   for         10
# 3  just         10
# 4   one         10
#   word  frequency
# 0   my         28
# 1   oh         19
# 2  the         19
# 3  you         18
# 4   of         17
#        word  frequency
# 0       the         10
# 1    future          8
# 2  futureno          8
# 3      save          8
# 4        no          6
#   word  frequency
# 0  the         29
# 1  you         15
# 2    a         11
# 3   to         11
# 4   on          9
#    word  frequency
# 0   you         22
# 1  only          8
# 2   the          8
# 3  will          7
# 4   and          6
#   word  frequency
# 0  the         62
# 1  you         50
# 2   me         41
# 3   it         36
# 4   on         33
#     word  frequency
# 0   feel         26
# 1  lovei         14
# 2      i         12
# 3    you         12
# 4   love         10
#      word  frequency
# 0  jammin         38
# 1       i         14
# 2    were         14
# 3     jam         12
# 4     you         12
#   word  frequency
# 0    i         34
# 1   to         29
# 2  you         20
# 3   my         16
# 4  all         13
#            word  frequency
# 0           the         29
# 1           put         28
# 2            on         27
# 3           red         27
# 4  lightroxanne         22
#   word  frequency
# 0  the         21
# 1   in          6
# 2  you          6
# 3   he          5
# 4   of          5
#   word  frequency
# 0    a         10
# 1    i          9
# 2  and          6
# 3  had          6
# 4  the          6
#    word  frequency
# 0   the         40
# 1    of         19
# 2  funk         17
# 3     a         16
# 4  stop         16
#       word  frequency
# 0       to          8
# 1       be          4
# 2     cant          4
# 3  control          4
# 4      goi          4
#    word  frequency
# 0   you         11
# 1  been          9
# 2     i          9
# 3  miss          7
# 4   the          6
#         word  frequency
# 0      freak         45
# 1       cest         21
# 2      outle         21
# 3  chicfreak         20
# 4      outah         17
#    word  frequency
# 0   old         17
# 1   and         16
# 2   the         16
# 3  rock         15
# 4  time         15
#            word  frequency
# 0          rock         18
# 1             a         16
# 2  ewwscadobada         12
# 3       lobster         12
# 4            in          8
#    word  frequency
# 0    in         19
# 1   the         16
# 2   you         12
# 3   all         11
# 4  dont         11
#       word  frequency
# 0      the         19
# 1        i         11
# 2  calling         10
# 3       is         10
# 4      and          6
#   word  frequency
# 0  the        193
# 1   of         99
# 2  and         72
# 3   to         61
# 4    a         57
#          word  frequency
# 0         the         29
# 1         are         23
# 2        good         23
# 3  timesthese         11
# 4   timesgood          9
#    word  frequency
# 0  stop         53
# 1    on         43
# 2   the         43
# 3  dont         41
# 4   you         40
#         word  frequency
# 0        are         15
# 1        and         10
# 2        all          8
# 3         up          8
# 4  everybody          7
#   word  frequency
# 0  you          9
# 1    i          8
# 2   on          8
# 3    a          6
# 4  the          6
#     word  frequency
# 0    hot         36
# 1  stuff         22
# 2   baby         21
# 3   some         19
# 4   need         13
# ...
# 4   in          6
#     word  frequency
# 0     we         14
# 1   bout         12
# 2   care         12
# 3    the         12
# 4  about          9
#    word  frequency
# 0   the         12
# 1     a         11
# 2  your          9
# 3    in          8
# 4   was          8
#     word  frequency
# 0      i         29
# 1    and         22
# 2  a—and         12
# 3     do         12
# 4    is—         12
#                word  frequency
# 0               ayy         35
# 1                my         20
# 2               the         15
# 3  umbrellaellaella         12
# 4                be         11
#       word  frequency
# 0      the         30
# 1        i         10
# 2      you         10
# 3  friends          9
# 4       if          8
#   word  frequency
# 0  the         45
# 1    i         18
# 2  and         16
# 3  flo         16
# 4  hit         16
#    word  frequency
# 0   the         13
# 1    no         12
# 2   one         12
# 3  what         11
# 4   get          9
#     word  frequency
# 0     it         31
# 1      i         25
# 2  never         21
# 3  right         21
# 4    you         20
#     word  frequency
# 0    the         45
# 1     do         14
# 2  dance         13
# 3    you         11
# 4      a         10
#    word  frequency
# 0  feat         43
# 1   the         26
# 2   lil         16
# 3    it         10
# 4    me         10
#     word  frequency
# 0    sie         11
# 1   face         10
# 2    ich          8
# 3    auf          7
# 4  bitch          7
#   word  frequency
# 0  you         10
# 1  and          8
# 2  the          8
# 3   as          7
# 4   on          7
#    word  frequency
# 0    oh         69
# 1   you         48
# 2     a         22
# 3    on         22
# 4  like         20
#    word  frequency
# 0   the         16
# 1     i         12
# 2    my         11
# 3  ohoh         10
# 4     a          7
#     word  frequency
# 0     it         15
# 1  dance         12
# 2     be         11
# 3      i         10
# 4     my         10
#    word  frequency
# 0   mum         31
# 1  read         30
# 2    my         22
# 3  cant         20
# 4    me         14
#      word  frequency
# 0      so         11
# 1       a          9
# 2    girl          9
# 3  kissed          9
# 4   liked          9
#   word  frequency
# 0   to         13
# 1   no         12
# 2    i         10
# 3  and          9
# 4   is          8
#     word  frequency
# 0  youre         35
# 1   then         28
# 2    you          9
# 3     in          8
# 4    its          8
#   word  frequency
# 0   is          5
# 1   on          5
# 2  sex          5
# 3  the          4
# 4   to          3
#       word  frequency
# 0       it          8
# 1     like          8
# 2        i          7
# 3      let          7
# 4  outdont          6
#     word  frequency
# 0    bum         57
# 1  bedum         32
# 2    you         23
# 3    the         16
# 4     in         10
#    word  frequency
# 0    it         52
# 1    do         42
# 2  good         32
# 3     a         29
# 4    be         24
#    word  frequency
# 0  boom         67
# 1  that         33
# 2   the         26
# 3   get         20
# 4  beat         19
#    word  frequency
# 0   the         25
# 1  york         20
# 2   new         17
# 3   you         17
# 4     a         14
#       word  frequency
# 0        i         37
# 1       my         34
# 2        a         28
# 3      and         24
# 4  fathers         19
#   word  frequency
# 0  you          6
# 1  all          5
# 2  the          5
# 3   as          4
# 4   me          4
#              word  frequency
# 0           seksī         18
# 1              tu         14
# 2      meičavelns          6
# 3  slampasasodīts          6
# 4        slampatu          6
#    word  frequency
# 0   hey         22
# 1    it         17
# 2  fold         15
# 3   you          8
# 4     a          5
#     word  frequency
# 0   down         28
# 1     go         26
# 2     my         25
# 3    you         24
# 4  right         20
#    word  frequency
# 0  this         12
# 1     i         10
# 2    me          8
# 3   the          6
# 4  your          6
#     word  frequency
# 0    the         35
# 1   know         28
# 2  enemy         19
# 3    you         18
# 4   your         13
#     word  frequency
# 0    had         26
# 1    the         26
# 2  gonna         24
# 3    you         23
# 4     in         20
#    word  frequency
# 0   you         30
# 1  fuck         16
# 2     i         16
# 3   the         15
# 4  that         12
#      word  frequency
# 0     run         34
# 1     the         31
# 2  better         28
# 3      my         16
# 4    with         16
#   word  frequency
# 0  you         17
# 1    i         15
# 2  her          9
# 3  the          9
# 4  way          9
#    word  frequency
# 0   the         33
# 1    im         21
# 2  only         19
# 3   you         17
# 4    in         15
#      word  frequency
# 0     que         21
# 1      de         20
# 2  mírate         19
# 3     los         13
# 4     por         13
#   word  frequency
# 0  awe         18
# 1    a         16
# 2  the         16
# 3   em         12
# 4  you         12
#   word  frequency
# 0    i          8
# 1   to          7
# 2   me          4
# 3  how          3
# 4  its          3
#          word  frequency
# 0          de         18
# 1          el         14
# 2          la         14
# 3  california         10
# 4       costa          9
#    word  frequency
# 0  come         39
# 1    on         28
# 2  like         26
# 3    it         17
# 4   and         16
#    word  frequency
# 0  that         23
# 1     i         19
# 2    to         18
# 3   you         16
# 4  used         12
#    word  frequency
# 0  born         39
# 1  this         37
# 2   was         29
# 3   hey         20
# 4   way         18
#     word  frequency
# 0   your         25
# 1  hands         21
# 2    the         20
# 3     up         19
# 4    put         13
#            word  frequency
# 0           the         21
# 1             i          9
# 2            me          9
# 3  nananananana          9
# 4           are          8
#     word  frequency
# 0   like         22
# 1  moves         18
# 2   them         16
# 3    you         14
# 4    and         13
#        word  frequency
# 0        in         19
# 1         a         17
# 2  hopeless         17
# 3     found         16
# 4      love         16
#   word  frequency
# 0   it         14
# 1  you         11
# 2  but         10
# 3    i         10
# 4  the         10
#    word  frequency
# 0     à         43
# 1    eu         21
# 2     o         19
# 3   que         19
# 4  tudo         18
#      word  frequency
# 0      at         22
# 1    girl         18
# 2    look         18
# 3    that         18
# 4  bodyah         17
#    word  frequency
# 0   you         26
# 1    so         23
# 2    my         20
# 3    me         14
# 4  call         12
#     word  frequency
# 0      옵         20
# 1     강남         12
# 2      너          8
# 3    옵오빤          7
# 4  lady옵          6
#   word  frequency
# 0  you         22
# 1  the         16
# 2   to         15
# 3   of         12
# 4   my         11
#      word  frequency
# 0    like         38
# 1       a         28
# 2  bright         27
# 3     the         21
# 4      in         15
#     word  frequency
# 0   live         21
# 1   were         18
# 2  while         15
# 3     we         14
# 4   lets         13
#    word  frequency
# 0  yeah         32
# 1    me         12
# 2   too         12
# 3  make          8
# 4   you          8
#      word  frequency
# 0       a         14
# 1     the         12
# 2  higher          9
# 3    more          9
# 4    than          9
#     word  frequency
# 0     la         26
# 1  think         26
# 2    had         19
# 3      a         14
# 4     da         14
#       word  frequency
# 0       we         14
# 1      the         10
# 2  reached          8
# 3       so          8
# 4       it          7
#       word  frequency
# 0      you         26
# 1        i         16
# 2     bout         12
# 3  thinkin         11
# 4     been         10
#       word  frequency
# 0   belong         13
# 1     with         12
# 2      you         12
# 3       my          8
# 4  meyoure          6
#     word  frequency
# 0     up         20
# 1    all         19
# 2  night         19
# 3     to         12
# 4    get         11
#    word  frequency
# 0   hey         45
# 1   you         34
# 2   get         28
# 3  know         18
# 4  want         18
#         word  frequency
# 0        you         33
# 1         im         25
# 2      along         24
# 3  happyclap         24
# 4         if         24
#    word  frequency
# 0    in         13
# 1   ill         12
# 2    me          9
# 3  rule          9
# 4   the          9
#         word  frequency
# 0        the         11
# 1  featuring          5
# 2        all          3
# 3     eminem          3
# 4       iggy          3
#   word  frequency
# 0  are         66
# 1  you         58
# 2   my         46
# 3  the         42
# 4   of         40
#           word  frequency
# 0          the         18
# 1         goin         17
# 2           oh         17
# 3          its         16
# 4  timbergwoah         16
#    word  frequency
# 0     i         18
# 1    me         18
# 2  hear         17
# 3     a         16
# 4   the         15
#       word  frequency
# 0      ive         36
# 1      the         29
# 2     been         28
# 3     that         23
# 4  countin         14
#       word  frequency
# 0       la         17
# 1      tes         12
# 2       et         10
# 3       tu         10
# 4  attends          9
#         word  frequency
# 0         by          6
# 1  featuring          6
# 2        the          6
# 3          –          6
# 4   directed          5
#    word  frequency
# 0  your         13
# 1    my         10
# 2   the         10
# 3    we         10
# 4  love          9
#    word  frequency
# 0     i         26
# 1     a         10
# 2  need         10
# 3  when         10
# 4    is          8
#    word  frequency
# 0  with          9
# 1  stay          8
# 2     i          7
# 3    to          7
# 4   you          7
#     word  frequency
# 0  shake         62
# 1      i         45
# 2     it         36
# 3  gonna         22
# 4    off         21
#    word  frequency
# 0   you         20
# 1    me         15
# 2    on         15
# 3    it         14
# 4  down         12
#     word  frequency
# 0    and         17
# 1   said         15
# 2   shut         12
# 3     up         12
# 4  dance         11
#    word  frequency
# 0  that         46
# 1  bass         31
# 2  bout         30
# 3   all         23
# 4    no         18
#    word  frequency
# 0  been          9
# 1    on          9
# 2  will          8
# 3   ive          7
# 4  what          7
#      word  frequency
# 0  united         55
# 1      of         11
# 2       —         10
# 3  grande          6
# 4   perry          6
#     word  frequency
# 0    you         14
# 1  highs         12
# 2   lows         12
# 3   that         10
# 4     it          8
#    word  frequency
# 0   you         22
# 1    my         16
# 2  when         16
# 3     i         13
# 4    me         13
#    word  frequency
# 0     i         46
# 1  love         30
# 2    it         24
# 3  cant         23
# 4  feel         19
#   word  frequency
# 0   be         29
# 1   we         28
# 2  gon         27
# 3  you         25
# 4  the         21
#    word  frequency
# 0   the         60
# 1     i         27
# 2   you         26
# 3  funk         14
# 4     a         13
#    word  frequency
# 0    we         25
# 1   got         22
# 2   bad         17
# 3   now         17
# 4  baby         16
#    word  frequency
# 0   you         46
# 1  like         34
# 2    me         32
# 3    do         23
# 4   the         13
#    word  frequency
# 0  that         13
# 1    my         12
# 2     i         11
# 3    im         11
# 4   you         11
#    word  frequency
# 0     i         16
# 1   all          6
# 2  back          5
# 3    im          5
# 4    my          5
#    word  frequency
# 0   you         49
# 1    do         29
# 2  mean         19
# 3    oh         17
# 4  what         17
#    word  frequency
# 0  feat         38
# 1   the         10
# 2   you          9
# 3     i          6
# 4    my          6
#     word  frequency
# 0      a         19
# 1     up         19
# 2   back         16
# 3  where         16
# 4      i         13
#     word  frequency
# 0    all         21
# 1   time         21
# 2    the         17
# 3  fifth         13
# 4    you         11
#     word  frequency
# 0      i         29
# 1  thats         26
# 2   what         26
# 3    you         26
# 4     it         19
#    word  frequency
# 0   the         18
# 1    to         18
# 2   you         17
# 3  dont         11
# 4  know          8
#         word  frequency
# 0       feat         12
# 1        the          4
# 2         my          3
# 3  something          3
# 4      about          2
#    word  frequency
# 0  feat         21
# 1    me          6
# 2   the          5
# 3  like          4
# 4  love          4
#   word  frequency
# 0  the         19
# 1  and         18
# 2  our         12
# 3   to         12
# 4  war         12
#       word  frequency
# 0      the         18
# 1       to         12
# 2     your         12
# 3  24karat         10
# 4     they         10
#     word  frequency
# 0   only         18
# 1  blame         16
# 2  human         16
# 3     on         16
# 4    put         16
#    word  frequency
# 0    my         33
# 1    in         27
# 2    on         26
# 3  love         23
# 4     i         22
#      word  frequency
# 0     hol         57
# 1      up         52
# 2    down         26
# 3     lil         24
# 4  humble         16
#            word  frequency
# 0             x          2
# 1  allamerikkan          1
# 2  automatonyfn          1
# 3          bada          1
# 4       badathe          1
#   word  frequency
# 0    a         15
# 1   tu         14
# 2  que         13
# 3   de          9
# 4   te          8
#    word  frequency
# 0     a         25
# 1  like         15
# 2   the         13
# 3    on         12
# 4    my         11
#   word  frequency
# 0    i         12
# 1  you         12
# 2   in         11
# 3   my         10
# 4  the          7
#      word  frequency
# 0  justin         23
# 1  bieber         21
# 2    feat         10
# 3     the          4
# 4  chance          3
#   word  frequency
# 0   it         22
# 1    a         12
# 2  for         12
# 3    i          9
# 4   im          9
#              word  frequency
# 0         thunder         51
# 1             the         26
# 2     thththunder         12
# 3  thunderthunder         12
# 4            feel          9
#   word  frequency
# 0   or         24
# 1   do         23
# 2   me         19
# 3  for         14
# 4  you         14
#     word  frequency
# 0    the         20
# 1      i          6
# 2  shaha          6
# 3    far          4
# 4   from          4
#     word  frequency
# 0   yeah         33
# 1  black         23
# 2    you         20
# 3   just         15
# 4    man         14
#   word  frequency
# 0  not         12
# 1  are          9
# 2  you          8
# 3   do          7
# 4    i          7
#      word  frequency
# 0  wishin         21
# 1     and         12
# 2      on         11
# 3    they         11
# 4       i          8
#     word  frequency
# 0    the          9
# 1   cant          8
# 2  gonna          8
# 3     me          8
# 4   tell          8
#     word  frequency
# 0    the         39
# 1    you         24
# 2  stars         18
# 3    all         17
# 4     me         10
#    word  frequency
# 0  like         58
# 1     i         57
# 2  said         26
# 3    it         25
# 4   the         23
#    word  frequency
# 0   the         26
# 1  like         17
# 2    my         16
# 3     a         12
# 4  with         12
#         word  frequency
# 0          i         33
# 1       cant         31
# 2        say         24
# 3  something         23
# 4        for         20
#         word  frequency
# 0        you         37
# 1  nextthank         18
# 2       next         16
# 3         so         13
# 4        for         11
#     word  frequency
# 0  gonna         12
# 1   cant         11
# 2     my         11
# 3    the         10
# 4      i          9
#    word  frequency
# 0   bad         10
# 1  your          9
# 2   the          7
# 3   you          6
# 4     a          5
#   word  frequency
# 0    i         18
# 1  you         14
# 2  for         11
# 3   me         11
# 4   it          9
#    word  frequency
# 0   the         13
# 1     i         12
# 2    im          8
# 3  cant          6
# 4   ooh          6
#    word  frequency
# 0   ooh         27
# 1     i         20
# 2    im         18
# 3  with         17
# 4  dont         16
#      word  frequency
# 0     you         31
# 1     the         23
# 2       a         15
# 3     for         14
# 4  sucker         14
#    word  frequency
# 0    it         47
# 1     i         43
# 2   got         19
# 3    my         18
# 4  want         18
#   word  frequency
# 0  the         18
# 1   my         12
# 2    i         10
# 3   in          6
# 4   it          6
#    word  frequency
# 0    me         35
# 1   you         24
# 2   and         16
# 3     i         15
# 4  hear         14
#    word  frequency
# 0  away         15
# 1   the         12
# 2   run          9
# 3   you          9
# 4     i          8

# %%
# Get Top 5 words used across all songs

#concatenate all lyrics
lyricsConcat = data['Lyrics'].str.cat(sep=' ')

# Split the text into words
words = lyricsConcat.split()

# Use Counter to count the frequency of each word
all_word_frequency = Counter(words)

all_word_frequency = sorted(all_word_frequency.items(), key=lambda item: (-item[1], item[0])) #sort frequencies

df_all_dict = pd.DataFrame(OrderedDict(all_word_frequency).items(),columns= ['word','frequency']) #convert sorted freqs to ordereddict and add data to df 

df_all_dict.head()
# Out:
#   word  frequency
# 0  the       9150
# 1  you       7615
# 2    i       6736
# 3    a       5012
# 4   to       4827

# %%
#Define and remove stop words
import nltk
#nltk.download('stopwords')
nltk.download('punkt')

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\theri\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
cleaned_tokens = []

# Get English stop words list
stop_words = set(stopwords.words('english'))


for i in range(0,data.shape[0]):
    
    # Tokenize the text
    tokens = word_tokenize(data['Lyrics'][i])
    
    # Remove stop words
    filtered_tokens = [word for word in tokens if word.lower() not in stop_words]
    
    # Reconstruct the text
    filtered_text = ' '.join(filtered_tokens)

    cleaned_tokens.append(filtered_text)

# %%
data['Lyrics'] = cleaned_tokens

# %%
data.head()
# Out:
#             Artist              Song  \
# 0            Adele           Skyfall
# 1       The Weeknd   Save Your Tears
# 2     Harry Styles  Watermelon Sugar
# 3         Doja Cat            Say So
# 4  Imagine Dragons           Thunder
#
#                                               Lyrics
# 0  end hold breath count ten feel earth move hear...
# 1  ooh nana yeah verse 1 verse 1 saw dancing crow...
# 2  tastes like strawberries summer evenin sounds ...
# 3  day night morning keep moment id let iu2005kno...
# 4  young gun quick fuse uptight wan na let loose ...

# %% [markdown]
# ### Removing words that are common among the entire dataset could strengthen the model if the those words don't add additional value

# %% [markdown]
# ### For now, I will remove the words 'verse', 'bridge', and 'chorus' since I know these words indicate sections of the song are not lyrics

# %%
data['Lyrics'] = data['Lyrics'].apply(lambda x: x.replace('chorus','').replace('verse','').replace('bridge','')
                                     if isinstance(x, str) else x)

# %%
#save lyric data to text file
data['Lyrics'].to_csv('input.csv', index=False, header=False, sep='\t')

# %% [markdown]
# # Finetune trained model with my lyrics data

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer, GPT2Config
from transformers import TextDataset, DataCollatorForLanguageModeling
from transformers import Trainer, TrainingArguments

# %%
# Load pre-trained GPT-2 model and tokenizer
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)

# Load your dataset
train_dataset = TextDataset(
    tokenizer=tokenizer,
    file_path='input.csv',  # Replace with the path to your dataset
    block_size=128  # Adjust block size as needed
)

# Create a data collator for language modeling
data_collator = DataCollatorForLanguageModeling(
    tokenizer=tokenizer,
    mlm=False  # For language modeling tasks, mlm should be set to False
)

# Fine-tuning arguments
if not os.path.exists('output2'):
    try:
        os.makedirs('output2')
    except OSError as e:
        print (e)
else:
    print(f"Folder already exists.")


training_args = TrainingArguments(
    output_dir="output",  # Replace with the path where you want to save the fine-tuned model
    overwrite_output_dir=True,
    num_train_epochs=10,  # Adjust as needed
    per_device_train_batch_size=4,  # Adjust batch size as needed
    save_total_limit=2,
    logging_steps=2,

)

# Create Trainer
trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=data_collator,
    train_dataset=train_dataset,
)

# Fine-tune the model
trainer.train()

# Save the fine-tuned model
model.save_pretrained("output2")
tokenizer.save_pretrained("output2")
# Out:
# C:\Users\theri\anaconda3\envs\nlp\Lib\site-packages\transformers\data\datasets\language_modeling.py:53: FutureWarning: This dataset will be removed from the library soon, preprocessing should be handled with the 🤗 Datasets library. You can have a look at this example script for pointers: https://github.com/huggingface/transformers/blob/main/examples/pytorch/language-modeling/run_mlm.py
#   warnings.warn(
# Folder already exists.
#     <div>
#
#       <progress value='970' max='970' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [970/970 3:00:15, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>2</td>
#       <td>4.757000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.550100</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.810100</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.114100</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>4.603900</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>4.050000</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>4.289900</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.928900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>4.630600</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>4.062900</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>4.004200</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>4.049000</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>3.599500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>4.134500</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>4.226900</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>3.813700</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>3.917100</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>4.071400</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>3.880900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>3.440000</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>3.595900</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>4.352500</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>4.169000</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.570500</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>4.206000</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>3.451400</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>4.055400</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>4.008200</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>3.751600</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>3.747400</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>3.837300</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>3.776800</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>3.606300</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>3.730900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>4.351800</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>3.628000</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>3.289300</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>3.532600</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>2.916900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>3.318300</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>3.921000</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>3.691100</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>3.805200</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>3.489300</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>3.640500</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>3.739100</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>3.543300</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>3.796100</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>4.013300</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>3.622900</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>3.257000</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>3.522100</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>3.601000</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>4.041900</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>3.375300</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>3.633600</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>3.680200</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>3.156900</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>3.650000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>3.781900</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>3.297100</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>3.075500</td>
#     </tr>
#     <tr>
#       <td>126</td>
#       <td>3.451200</td>
#     </tr>
#     <tr>
#       <td>128</td>
#       <td>3.386200</td>
#     </tr>
#     <tr>
#       <td>130</td>
#       <td>3.379200</td>
#     </tr>
#     <tr>
#       <td>132</td>
#       <td>3.437100</td>
#     </tr>
#     <tr>
#       <td>134</td>
#       <td>3.293000</td>
#     </tr>
#     <tr>
#       <td>136</td>
#       <td>3.189500</td>
#     </tr>
#     <tr>
#       <td>138</td>
#       <td>3.211500</td>
#     </tr>
#     <tr>
#       <td>140</td>
#       <td>3.412100</td>
#     </tr>
#     <tr>
#       <td>142</td>
#       <td>4.108100</td>
#     </tr>
#     <tr>
#       <td>144</td>
#       <td>3.630500</td>
#     </tr>
#     <tr>
#       <td>146</td>
#       <td>3.167300</td>
#     </tr>
#     <tr>
#       <td>148</td>
#       <td>3.155100</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>2.870100</td>
#     </tr>
#     <tr>
#       <td>152</td>
#       <td>3.520500</td>
#     </tr>
#     <tr>
#       <td>154</td>
#       <td>3.084800</td>
#     </tr>
#     <tr>
#       <td>156</td>
#       <td>2.852800</td>
#     </tr>
#     <tr>
#       <td>158</td>
#       <td>3.305600</td>
#     </tr>
#     <tr>
#       <td>160</td>
#       <td>3.144400</td>
#     </tr>
#     <tr>
#       <td>162</td>
#       <td>3.418100</td>
#     </tr>
#     <tr>
#       <td>164</td>
#       <td>3.688200</td>
#     </tr>
#     <tr>
#       <td>166</td>
#       <td>3.485000</td>
#     </tr>
#     <tr>
#       <td>168</td>
#       <td>3.645400</td>
#     </tr>
#     <tr>
#       <td>170</td>
#       <td>3.509600</td>
#     </tr>
#     <tr>
#       <td>172</td>
#       <td>3.310300</td>
#     </tr>
#     <tr>
#       <td>174</td>
#       <td>3.076300</td>
#     </tr>
#     <tr>
#       <td>176</td>
#       <td>3.526600</td>
#     </tr>
#     <tr>
#       <td>178</td>
#       <td>3.403300</td>
#     </tr>
#     <tr>
#       <td>180</td>
#       <td>3.314700</td>
#     </tr>
#     <tr>
#       <td>182</td>
#       <td>2.800100</td>
#     </tr>
#     <tr>
#       <td>184</td>
#       <td>3.459600</td>
#     </tr>
#     <tr>
#       <td>186</td>
#       <td>3.195100</td>
#     </tr>
#     <tr>
#       <td>188</td>
#       <td>3.112000</td>
#     </tr>
#     <tr>
#       <td>190</td>
#       <td>3.165500</td>
#     </tr>
#     <tr>
#       <td>192</td>
#       <td>3.276300</td>
#     </tr>
#     <tr>
#       <td>194</td>
#       <td>3.181900</td>
#     </tr>
#     <tr>
#       <td>196</td>
#       <td>3.288600</td>
#     </tr>
#     <tr>
#       <td>198</td>
#       <td>3.136800</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>2.755200</td>
#     </tr>
#     <tr>
#       <td>202</td>
#       <td>3.059700</td>
#     </tr>
#     <tr>
#       <td>204</td>
#       <td>2.874600</td>
#     </tr>
#     <tr>
#       <td>206</td>
#       <td>3.311900</td>
#     </tr>
#     <tr>
#       <td>208</td>
#       <td>3.331400</td>
#     </tr>
#     <tr>
#       <td>210</td>
#       <td>2.828100</td>
#     </tr>
#     <tr>
#       <td>212</td>
#       <td>2.952100</td>
#     </tr>
#     <tr>
#       <td>214</td>
#       <td>2.732900</td>
#     </tr>
#     <tr>
#       <td>216</td>
#       <td>3.009000</td>
#     </tr>
#     <tr>
#       <td>218</td>
#       <td>2.757000</td>
#     </tr>
#     <tr>
#       <td>220</td>
#       <td>3.046000</td>
#     </tr>
#     <tr>
#       <td>222</td>
#       <td>3.329500</td>
#     </tr>
#     <tr>
#       <td>224</td>
#       <td>2.949800</td>
#     </tr>
#     <tr>
#       <td>226</td>
#       <td>3.433700</td>
#     </tr>
#     <tr>
#       <td>228</td>
#       <td>3.023300</td>
#     </tr>
#     <tr>
#       <td>230</td>
#       <td>2.924900</td>
#     </tr>
#     <tr>
#       <td>232</td>
#       <td>2.855000</td>
#     </tr>
#     <tr>
#       <td>234</td>
#       <td>2.765400</td>
#     </tr>
#     <tr>
#       <td>236</td>
#       <td>2.715400</td>
#     </tr>
#     <tr>
#       <td>238</td>
#       <td>3.155500</td>
#     </tr>
#     <tr>
#       <td>240</td>
#       <td>3.287700</td>
#     </tr>
#     <tr>
#       <td>242</td>
#       <td>3.342200</td>
#     </tr>
#     <tr>
#       <td>244</td>
#       <td>2.943400</td>
#     </tr>
#     <tr>
#       <td>246</td>
#       <td>3.182100</td>
#     </tr>
#     <tr>
#       <td>248</td>
#       <td>3.281200</td>
#     </tr>
#     <tr>
#       <td>250</td>
# ('output2\\tokenizer_config.json',
#  'output2\\special_tokens_map.json',
#  'output2\\vocab.json',
#  'output2\\merges.txt',
#  'output2\\added_tokens.json')

# %% [markdown]
# # Testing The Model

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# Define the directory where the fine-tuned model and tokenizer are saved
model_directory = "output2"

# Load the fine-tuned model and tokenizer
try:
    model = GPT2LMHeadModel.from_pretrained(model_directory)
    tokenizer = GPT2Tokenizer.from_pretrained(model_directory)
except Exception as e:
    print("Error loading model and tokenizer:", e)
    # Handle the error accordingly, such as providing a more informative message or exiting gracefully

# %%
# Define a function for searching songs based on user queries
def search_songs(query, data, model, tokenizer):
    # Encode the user query
    input_ids = tokenizer.encode(query, return_tensors="pt")

    # Generate an attention mask
    attention_mask = torch.ones(input_ids.shape, dtype=torch.long, device=input_ids.device)

    # Generate a response from the model
    output = model.generate(input_ids, attention_mask=attention_mask, pad_token_id=tokenizer.eos_token_id, max_new_tokens=20)

    # Decode and return the generated response
    decoded_response = tokenizer.decode(output[0], skip_special_tokens=True)
    return decoded_response

# %%
# Example usage
user_query = "what are some songs about cars?"
result = search_songs(user_query, data, model, tokenizer)
print(result)
# Out:
# what are some songs about cars?   i dont know why i dont know why i dont know why i dont know why i dont
